# %%
# !pip install -r requirements.txt
# !pip install numba
# Out:
# Requirement already satisfied: pytest>=6.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (9.0.2)
# Requirement already satisfied: hypothesis>=6.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (6.151.9)
# Requirement already satisfied: streamlit>=1.12.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.54.0)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.10.8)
# Requirement already satisfied: numpy>=1.21.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.4.2)
# Requirement already satisfied: black>=22.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (26.1.0)
# Requirement already satisfied: flake8>=4.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (7.3.0)
# Requirement already satisfied: numba in /home/poridhian/code/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.64.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pytest>=6.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: packaging>=22 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pytest>=6.0->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pytest>=6.0->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pytest>=6.0->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from hypothesis>=6.0->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (3.1.46)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from streamlit>=1.12.0->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: jinja2 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.12.0->-r requirements.txt (line 3)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.12.0->-r requirements.txt (line 3)) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.12.0->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.12.0->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.12.0->-r requirements.txt (line 3)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.12.0->-r requirements.txt (line 3)) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from black>=22.0->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from black>=22.0->-r requirements.txt (line 6)) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from black>=22.0->-r requirements.txt (line 6)) (4.9.2)
# Requirement already satisfied: pytokens>=0.3.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from black>=22.0->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from flake8>=4.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from flake8>=4.0->-r requirements.txt (line 7)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from flake8>=4.0->-r requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from numba->-r requirements.txt (line 8)) (0.46.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: six>=1.5 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.12.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: numba in /home/poridhian/code/.venv/lib/python3.12/site-packages (0.64.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from numba) (0.46.0)
# Requirement already satisfied: numpy<2.5,>=1.22 in /home/poridhian/code/.venv/lib/python3.12/site-packages (from numba) (2.4.2)

# %%
# !python project/run_fast_tensor.py --BACKEND gpu --HIDDEN 100 --DATASET split
# Out:
# Traceback (most recent call last):
#   File "/home/poridhian/code/minitorch-fundamentals/project/run_fast_tensor.py", line 2, in <module>
#     import minitorch
# ModuleNotFoundError: No module named 'minitorch'
